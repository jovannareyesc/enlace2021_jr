# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2
df = pd.read_excel('../data/Educacion_01.xlsx',skiprows = range(0, 3))
df.head()
# Out:
#          Entidad federativa       Total  Sabe leer y escribir  \
# 0  Estados Unidos Mexicanos  19529018.0            17554529.0
# 1            Aguascalientes    234498.0              216002.0
# 2           Baja California    553060.0              495977.0
# 3       Baja California Sur    121220.0              107786.0
# 4                  Campeche    145473.0              129890.0
#
#    No sabe leer y escribir  No especificado
# 0                1871713.0         102776.0
# 1                  17770.0            726.0
# 2                  52605.0           4478.0
# 3                  12780.0            654.0
# 4                  14959.0            624.0

# %%
df.rename(columns={'Entidad federativa': 'state', 'Sabe leer y escribir': 'read_write', 'No sabe leer y escribir': 'not_read_write', 'No especificado' : 'not_specified'} , inplace=True)

# %%
df.query('state != "Estados Unidos Mexicanos"', inplace = True)
df.head()
# Out:
#                   state     Total  read_write  not_read_write  not_specified
# 1        Aguascalientes  234498.0    216002.0         17770.0          726.0
# 2       Baja California  553060.0    495977.0         52605.0         4478.0
# 3   Baja California Sur  121220.0    107786.0         12780.0          654.0
# 4              Campeche  145473.0    129890.0         14959.0          624.0
# 5  Coahuila de Zaragoza  486221.0    445183.0         39038.0         2000.0

# %%
df['pct_read_write'] = df['read_write']/df['Total']*100
df['pct_not_read_write'] = df['not_read_write']/df['Total']*100
df.head()
# Out:
#                   state     Total  read_write  not_read_write  not_specified  \
# 1        Aguascalientes  234498.0    216002.0         17770.0          726.0
# 2       Baja California  553060.0    495977.0         52605.0         4478.0
# 3   Baja California Sur  121220.0    107786.0         12780.0          654.0
# 4              Campeche  145473.0    129890.0         14959.0          624.0
# 5  Coahuila de Zaragoza  486221.0    445183.0         39038.0         2000.0
#
#    pct_read_write  pct_not_read_write
# 1       92.112513            7.577890
# 2       89.678697            9.511626
# 3       88.917670           10.542815
# 4       89.288047           10.283008
# 5       91.559805            8.028859

# %%
df['state'] = df['state'].str.upper()
df.head()
# Out:
#                   state     Total  read_write  not_read_write  not_specified  \
# 1        AGUASCALIENTES  234498.0    216002.0         17770.0          726.0
# 2       BAJA CALIFORNIA  553060.0    495977.0         52605.0         4478.0
# 3   BAJA CALIFORNIA SUR  121220.0    107786.0         12780.0          654.0
# 4              CAMPECHE  145473.0    129890.0         14959.0          624.0
# 5  COAHUILA DE ZARAGOZA  486221.0    445183.0         39038.0         2000.0
#
#    pct_read_write  pct_not_read_write
# 1       92.112513            7.577890
# 2       89.678697            9.511626
# 3       88.917670           10.542815
# 4       89.288047           10.283008
# 5       91.559805            8.028859

# %%
df = df.iloc[0:32,:].copy()
df.sort_values(by=['state'], ascending = True, inplace=True)
df.at[9,'state']='DISTRITO FEDERAL'
df.at[5,'state']='COAHUILA'
# 31            ZACATECAS     1666426        31031  1862.128891      56.228119
#
#     total_deaths  rates_deaths  rates_deaths60
# 0           2456    171.193370        5.924852
# 1           8648    237.917856        4.786969
# 2           1486    184.663257       14.415167
# 3           1265    126.421998        5.596547
# 4           1654     28.863771        0.715486
# 5           7493    197.107079       10.758948
# 6           6376    198.091167        2.081573
# 7           1210    154.110091        4.330366
# 8          34458    382.075134        7.096410
# 9           2495    133.494133        3.691822
# 10         11079    177.885175        1.878560
# 11          4547    124.335256        4.757936
# 12          6268    203.083579        4.730409
# 13         12604    149.874674        3.139235
# 14         37207    213.492359        4.171499
# 15          5938    123.057130        5.222364
# 16          3536    172.989220        8.218945
# 17          1868    144.966789        5.277164
# 18          9692    172.758212        3.671914
# 19          3896     94.024679        2.847770
# 20         12171    184.284810        8.040032
# 21          4452    195.294251        6.272929
# 22          2940    170.606972       19.439910
# 23          5428    189.383499        3.523901
# 24          6362    201.541242        6.240746
# 25          6739    219.172647        4.683315
# 26          4234    164.600606        6.764408
# 27          5167    141.538300        7.231684
# 28          2525    182.969556        2.898528
# 29         10063    117.835628        2.974287
# 30          4098    181.399833       14.784662
# 31          2832    169.944540        4.140598

# %%
dfAll = pd.merge(df,dfWeek1,on='state')
df.shape
# Out:
# (32, 7)

# %%
plt.figure(figsize=(14,10))
sns.regplot(x="total_cases", y="pct_not_read_write", data=dfAll)
sns.set_context('paper', font_scale=2)

# %%
plt.figure(figsize=(14,10))
sns.regplot(x="total_cases", y="pct_read_write", data=dfAll)
sns.set_context('paper', font_scale=2)

# %%
df = pd.read_excel('../data/Educacion_05.xlsx',skiprows = range(0, 4))
df.head()
# Out:
#          Entidad federativa  Total
# 0  Estados Unidos Mexicanos   9.74
# 1            Aguascalientes  10.35
# 2           Baja California  10.20
# 3       Baja California Sur  10.34
# 4                  Campeche   9.63

# %%
df.rename(columns={'Entidad federativa': 'state', 'Total' : 'average_years_finish'} , inplace=True)
df.query('state != "Estados Unidos Mexicanos"', inplace = True)
df.head()
# Out:
#                   state  average_years_finish
# 1        Aguascalientes                 10.35
# 2       Baja California                 10.20
# 3   Baja California Sur                 10.34
# 4              Campeche                  9.63
# 5  Coahuila de Zaragoza                 10.43

# %%
sns.pairplot(df[['pct_read_write', 'pct_not_read_write']]);
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-16-11f1b16885e8> in <module>
# ----> 1 sns.pairplot(df[['pct_read_write', 'pct_not_read_write']]);
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3028             if is_iterator(key):
#    3029                 key = list(key)
# -> 3030             indexer = self.loc._get_listlike_indexer(key, axis=1, raise_missing=True)[1]
#    3031
#    3032         # take() does not accept boolean indexers
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1264             keyarr, indexer, new_indexer = ax._reindex_non_unique(keyarr)
#    1265
# -> 1266         self._validate_read_indexer(keyarr, indexer, axis, raise_missing=raise_missing)
#    1267         return keyarr, indexer
#    1268
#
# ~/opt/miniconda3/lib/python3.9/site-packages/pandas/core/indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1306             if missing == len(indexer):
#    1307                 axis_name = self.obj._get_axis_name(axis)
# -> 1308                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1309
#    1310             ax = self.obj._get_axis(axis)
#
# KeyError: "None of [Index(['pct_read_write', 'pct_not_read_write'], dtype='object')] are in the [columns]"
